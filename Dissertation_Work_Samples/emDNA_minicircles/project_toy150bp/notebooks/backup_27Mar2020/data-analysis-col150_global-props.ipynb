# %% [markdown]
# # 2018 Col150 Data Set
# ## Data and Graphical Analysis

# %%
import os, sys, shutil, subprocess
import scipy
from scipy import ndimage
from scipy.spatial import distance

import numpy as np
import pandas as pd

from sklearn.decomposition import PCA

import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
matplotlib.rcParams.update({'figure.max_open_warning': 0})
matplotlib.rcParams.update({'font.size': 12})


# %matplotlib inline
path = os.getcwd()

# %%
Ncirc = 150
ematrix_dict = {0:'tilt', 1:'roll', 2:'twist', 3:'shift', 4:'slide', 5:'rise'}

incons   = ['oring','pcirc']

inseqs1   = ['col'+str(i).zfill(2) for i in range(1, 10, 1)]
inseqs2   = ['A150','G150','A75G75','A15G15','A1G1','A2G2','A3G3','A4G4','A5G5']

seqvars        = ['std','c05a','c15a','c20a','c30a']
seqvars_colors = {'std':'grey','c05a':'blue','c15a':'red','c20a':'gold','c30a':'green'}
seqvars_marks  = {'std':'s','c05a':'<','c15a':'^','c20a':'d','c30a':'P'}

ff_dict       = {'idt':'1-state','org':'2-state','vic':'3-state','vor':'4-state'}

ff_st         = [str(i)+'-state' for i in range(1, 5, 1)]
ff_st_dict    = {'1-state':'ideal','2-state':'oring','3-state':'zhurkin','4-state':'zhurkin+oring'}
ff_st_colors  = {'1-state':'gold','2-state':'dodgerblue','3-state':'limegreen','4-state':'tomato'}
ff_st_marks   = {'1-state':'.','2-state':'.','3-state':'.','4-state':'.'}

ff_ind         = ['ideal','kabsch','olson']
ff_ind_colors  = {'ideal':'darkgreen','kabsch':'crimson','olson':'dodgerblue'}
ff_ind_marks   = {'ideal':'.','kabsch':'^','olson':'d'}

rs_bpt             = ['090','091','092','093','094','095','096','097','098','099','100',
                     '101','012','103','104','105','106','107','108','109','110']
rs_bpturn          = [9.0,9.1,9.2,9.3,9.4,9.5,9.6,9.7,9.8,9.9,10.0,
                      10.1,10.2,10.3,10.4,10.5,10.6,10.7,10.8,10.9,11.0]
rs_tw              = [round(float(360/i), 2) for i in rs_bpturn]
colors             = plt.cm.gnuplot(np.linspace(0, 1, len(rs_tw)))
rs_tw_colors       = {i:j for i in rs_tw for j in plt.cm.gnuplot(np.linspace(0, 1, len(rs_tw)))}
rs_bpturn_colors   = {i:j for i in rs_bpturn for j in plt.cm.gnuplot(np.linspace(0, 1, len(rs_tw)))}
rs_bpt_colors      = {i:j for i in rs_bpt for j in plt.cm.gnuplot(np.linspace(0, 1, len(rs_tw)))}

# %%
def pca_df(filename):
    df   = pd.DataFrame(columns=['x','y','z'])
    infile = open(filename, 'r')
    rfdata = infile.readlines()
    infile.close()
    rfdata = [i.rstrip('\n').split() for i in rfdata]
    N = int(rfdata[0][0])
    for j in range(0, N):
        df.at[j, ['x','y','z']]  = rfdata[ 5*j + 2]

    df = df.astype('float')
    df['vx'] = df.x - df.x.mean()
    df['vy'] = df.y - df.y.mean()
    df['vz'] = df.z - df.z.mean()

    cxx = ( (df.vx*df.vx).sum() - (df.vx.sum() * df.vx.sum()) ) / (N-1)
    cxy = ( (df.vx*df.vy).sum() - (df.vx.sum() * df.vy.sum()) ) / (N-1)
    cxz = ( (df.vx*df.vz).sum() - (df.vx.sum() * df.vz.sum()) ) / (N-1)
    cyx = ( (df.vy*df.vx).sum() - (df.vy.sum() * df.vx.sum()) ) / (N-1)
    cyy = ( (df.vy*df.vy).sum() - (df.vy.sum() * df.vy.sum()) ) / (N-1)
    cyz = ( (df.vy*df.vz).sum() - (df.vy.sum() * df.vz.sum()) ) / (N-1)
    czx = ( (df.vz*df.vx).sum() - (df.vz.sum() * df.vx.sum()) ) / (N-1)
    czy = ( (df.vz*df.vy).sum() - (df.vz.sum() * df.vy.sum()) ) / (N-1)
    czz = ( (df.vz*df.vz).sum() - (df.vz.sum() * df.vz.sum()) ) / (N-1)

    covar = np.matrix([ [cxx, cxy, cxz], [cyx, cyy, cyz], [czx, czy, czz] ])
    evals, evecs = np.linalg.eig( covar )
    idx = np.argsort(evals)[::-1][: len(evals)]
    evals = evals[idx]
    evecs = evecs[:, idx]

    adj = pd.DataFrame(np.dot( df[['vx', 'vy', 'vz']], evecs), columns=['e1','e2','e3'])
    del rfdata, df
    return adj

def fig_move(figdirectory):
    for filename in os.listdir(figdirectory):
        if not os.path.exists("figures"):
            os.mkdir("figures")
    for filename in os.listdir(figdirectory):
        if filename.endswith(".png"):
            shutil.move(figdirectory+'/'+filename, figdirectory+"/figures/"+filename)
    return

def optparameterdf(file):
    infile = open(file,'r')
    indata = infile.readlines()
    infile.close()
    indata = [i.strip('\n').split() for i in indata]
    header = indata[2:3]
    pars   = indata[3:]
    # Ensure all objects in dataframe are float64
    for k in range(0, len(pars)):
        for j, x in enumerate(pars[k]):
            try:
                pars[k][j] = float(x)
            except ValueError:
                pass
    # Generate dataframe
    df = pd.DataFrame.from_records(pars, columns=header)
    # Generate new column: 'Bend'
    for k in range(0, len(df)):
        x = float(df.loc[k, 'Tilt'])
        y = float(df.loc[k, 'Roll'])
        df.loc[k, 'Bend'] = float(np.sqrt(x**2 + y**2))
    del header, pars
    return df

# %% [markdown]
# ## Load Global Data .csv file and analyze properties

# %%
# Load .csv files into dataframes
# --- Focus only on standard (stda) sequence types
df = pd.read_csv("data_col150_seq-primary_fullset", index_col=0)

col150_df = df[df.seq_type=='std']

col150_df
# Out:
#                         incon    seq seq_type forcefield    tw  tot_bp  \
# col01_oring_std_idt095  oring  col01     stda    1-state   9.5     150
# col01_oring_std_vic096  oring  col01     stda    3-state   9.6     150
# col01_oring_std_vor107  oring  col01     stda    4-state  10.7     150
# col01_oring_std_org100  oring  col01     stda    2-state  10.0     150
# col01_oring_std_vor096  oring  col01     stda    4-state   9.6     150
# col01_oring_std_vic092  oring  col01     stda    3-state   9.2     150
# col01_oring_std_vor100  oring  col01     stda    4-state  10.0     150
# col01_oring_std_vic091  oring  col01     stda    3-state   9.1     150
# col01_oring_std_kabsch  oring  col01     stda     kabsch   NaN     150
# col01_oring_std_vic090  oring  col01     stda    3-state   9.0     150
# col01_oring_std_org110  oring  col01     stda    2-state  11.0     150
# col01_oring_std_idt092  oring  col01     stda    1-state   9.2     150
# col01_oring_std_org094  oring  col01     stda    2-state   9.4     150
# col01_oring_std_vic093  oring  col01     stda    3-state   9.3     150
# col01_oring_std_org103  oring  col01     stda    2-state  10.3     150
# col01_oring_std_vor098  oring  col01     stda    4-state   9.8     150
# col01_oring_std_vic106  oring  col01     stda    3-state  10.6     150
# col01_oring_std_idt097  oring  col01     stda    1-state   9.7     150
# col01_oring_std_org096  oring  col01     stda    2-state   9.6     150
# col01_oring_std_vic097  oring  col01     stda    3-state   9.7     150
# col01_oring_std_org090  oring  col01     stda    2-state   9.0     150
# col01_oring_std_vor094  oring  col01     stda    4-state   9.4     150
# col01_oring_std_vor095  oring  col01     stda    4-state   9.5     150
# col01_oring_std_ideal   oring  col01     stda      ideal   NaN     150
# col01_oring_std_vic108  oring  col01     stda    3-state  10.8     150
# col01_oring_std_idt093  oring  col01     stda    1-state   9.3     150
# col01_oring_std_org108  oring  col01     stda    2-state  10.8     150
# col01_oring_std_idt110  oring  col01     stda    1-state  11.0     150
# col01_oring_std_idt091  oring  col01     stda    1-state   9.1     150
# col01_oring_std_org095  oring  col01     stda    2-state   9.5     150
# ...                       ...    ...      ...        ...   ...     ...
# col09_pcirc_std_idt108  pcirc  col09     stda    1-state  10.8     150
# col09_pcirc_std_org096  pcirc  col09     stda    2-state   9.6     150
# col09_pcirc_std_org106  pcirc  col09     stda    2-state  10.6     150
# col09_pcirc_std_vic091  pcirc  col09     stda    3-state   9.1     150
# col09_pcirc_std_vic104  pcirc  col09     stda    3-state  10.4     150
# col09_pcirc_std_vic109  pcirc  col09     stda    3-state  10.9     150
# col09_pcirc_std_ideal   pcirc  col09     stda      ideal   NaN     150
# col09_pcirc_std_vor102  pcirc  col09     stda    4-state  10.2     150
# col09_pcirc_std_idt098  pcirc  col09     stda    1-state   9.8     150
# col09_pcirc_std_idt094  pcirc  col09     stda    1-state   9.4     150
# col09_pcirc_std_olson   pcirc  col09     stda      olson   NaN     150
# col09_pcirc_std_org107  pcirc  col09     stda    2-state  10.7     150
# col09_pcirc_std_vic099  pcirc  col09     stda    3-state   9.9     150
# col09_pcirc_std_vor103  pcirc  col09     stda    4-state  10.3     150
# col09_pcirc_std_vor092  pcirc  col09     stda    4-state   9.2     150
# col09_pcirc_std_vic100  pcirc  col09     stda    3-state  10.0     150
# col09_pcirc_std_vor101  pcirc  col09     stda    4-state  10.1     150
# col09_pcirc_std_org092  pcirc  col09     stda    2-state   9.2     150
# col09_pcirc_std_vor108  pcirc  col09     stda    4-state  10.8     150
# col09_pcirc_std_vic093  pcirc  col09     stda    3-state   9.3     150
# col09_pcirc_std_idt110  pcirc  col09     stda    1-state  11.0     150
# col09_pcirc_std_vor091  pcirc  col09     stda    4-state   9.1     150
# col09_pcirc_std_org100  pcirc  col09     stda    2-state  10.0     150
# col09_pcirc_std_vic102  pcirc  col09     stda    3-state  10.2     150
# col09_pcirc_std_vor100  pcirc  col09     stda    4-state  10.0     150
# col09_pcirc_std_vic090  pcirc  col09     stda    3-state   9.0     150
# col09_pcirc_std_org098  pcirc  col09     stda    2-state   9.8     150
# col09_pcirc_std_vor096  pcirc  col09     stda    4-state   9.6     150
# col09_pcirc_std_idt097  pcirc  col09     stda    1-state   9.7     150
# col09_pcirc_std_org107  3.750162e-03 -8.517562e-01  14.851756  14.0  46.080321
# col09_pcirc_std_vic099  4.613521e-03  9.481601e-01  15.051840  16.0  50.696656
# col09_pcirc_std_vor103  5.063590e-05  1.506753e+01  14.932471  30.0  40.407955
# col09_pcirc_std_vor092  3.252926e-04  1.505752e+01  14.942482  30.0  40.435277
# col09_pcirc_std_vic100  2.898708e-03  1.004615e+00  14.995385  16.0  48.871764
# col09_pcirc_std_vor101  7.008800e-06  1.506574e+01  14.934263  30.0  40.412853
# col09_pcirc_std_org092  1.569939e-02  8.148547e-01  15.185145  16.0  57.012699
# col09_pcirc_std_vor108  3.260335e-04  1.507195e+01  14.928048  30.0  40.395861
# col09_pcirc_std_vic093  4.724713e-03  1.191356e-02  15.988086  16.0  80.995697
# col09_pcirc_std_idt110  1.400000e-09  2.348757e-11  14.000000  14.0  81.174944
# col09_pcirc_std_vor091  4.077629e-03  1.007692e+00  14.992308  16.0  44.340683
# col09_pcirc_std_org100  1.000000e-10  1.507865e+01  14.921352  30.0  40.377740
# col09_pcirc_std_vic102  1.124832e-02 -7.921523e-01  14.792152  14.0  57.228319
# col09_pcirc_std_vor100  1.543000e-07  1.506484e+01  14.935163  30.0  40.415314
# col09_pcirc_std_vic090  4.428398e-03  8.129644e-03  15.991870  16.0  81.072025
# col09_pcirc_std_org098  1.982900e-05  1.507638e+01  14.923618  30.0  40.383669
# col09_pcirc_std_vor096  7.639850e-05  1.506120e+01  14.938797  30.0  40.425237
# col09_pcirc_std_idt097  7.300000e-09  2.477385e-10  16.000000  16.0  81.174929
# col09_pcirc_std_idt095  2.000000e-10  7.000632e-11  16.000000  16.0  81.174951
#
# [1566 rows x 18 columns]

# %%
# Plot eopt, lk, wr, and rg for the 3 Models based on GroupA and GroupB
# --- GroupA: col01, col03, col04, col02
# --- GroupB: col05 - col09

# %%
for i in range(0, len(incons)):
    for j in range(0, len(inseqs1)):
        df2 = col150_df.loc[(col150_df.incon==incons[i])
                            &(col150_df.seq==inseqs1[j])
                            &(col150_df.tw != 'na')]
        
        fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)
        for key, grp in df2.groupby(['forcefield']):
            for key2, grp2 in grp.groupby(['seq_type']):
                if seqvars[0] == key2:
                    grp2.plot(kind='line', x='tw', y='eopt', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax1)
                elif seqvars[1] == key2:
                    grp2.plot(kind='line', x='tw', y='eopt', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax2)
                elif seqvars[2] == key2:
                    grp2.plot(kind='line', x='tw', y='eopt', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax3)
                elif seqvars[3] == key2:
                    grp2.plot(kind='line', x='tw', y='eopt', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax4)
                elif seqvars[4] == key2:
                    grp2.plot(kind='line', x='tw', y='eopt', c = statecolors[key], marker=statemarks[key], lw=1, legend=True, label=key, ax=ax5)
        
        ax1.set_ylim(0, 75)
        ax1.set_ylabel("Optimized Energy (kBT)")
        ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
        ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
        ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
        ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
        ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
        
        ax1.set_xlabel('base-pairs/helical turn')
        ax1.set_xticks(range(0, len(grp2.tw)))
        ax1.set_xticklabels(grp2.tw, rotation=90)
        ax2.set_xlabel('base-pairs/helical turn')
        ax2.set_xticks(range(0, len(grp2.tw)))
        ax2.set_xticklabels(grp2.tw, rotation=90)
        ax3.set_xlabel('base-pairs/helical turn')
        ax3.set_xticks(range(0, len(grp2.tw)))
        ax3.set_xticklabels(grp2.tw, rotation=90)
        ax4.set_xlabel('base-pairs/helical turn')
        ax4.set_xticks(range(0, len(grp2.tw)))
        ax4.set_xticklabels(grp2.tw, rotation=90)
        ax5.set_xlabel('base-pairs/helical turn')
        ax5.set_xticks(range(0, len(grp2.tw)))
        ax5.set_xticklabels(grp2.tw, rotation=90)
        
        plt.legend(loc="upper left", bbox_to_anchor=(1.03,1), fancybox=True)
        plt.tight_layout()
        plt.savefig("col150_Eopt_"+incons[i]+"_"+inseqs2[j]+"_4TwModel", dpi=200, transparent=True, bbox_inches='tight')
        #plt.show()
        plt.clf()
        
        fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)
        for key, grp in df2.groupby(['forcefield']):
            for key2, grp2 in grp.groupby(['seq_type']):
                if seqvars[0] == key2:
                    grp2.plot(kind='line', x='tw', y='Wr', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax1)
                elif seqvars[1] == key2:
                    grp2.plot(kind='line', x='tw', y='Wr', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax2)
                elif seqvars[2] == key2:
                    grp2.plot(kind='line', x='tw', y='Wr', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax3)
                elif seqvars[3] == key2:
                    grp2.plot(kind='line', x='tw', y='Wr', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax4)
                elif seqvars[4] == key2:
                    grp2.plot(kind='line', x='tw', y='Wr', c = statecolors[key], marker=statemarks[key], lw=1, legend=True, label=key, ax=ax5)
        
        ax1.set_ylim(-0.5, 0.5)
        ax1.set_ylabel("Writhe")
        ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
        ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
        ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
        ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
        ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
        
        ax1.set_xlabel('base-pairs/helical turn')
        ax1.set_xticks(range(0, len(grp2.tw)))
        ax1.set_xticklabels(grp2.tw, rotation=90)
        ax2.set_xlabel('base-pairs/helical turn')
        ax2.set_xticks(range(0, len(grp2.tw)))
        ax2.set_xticklabels(grp2.tw, rotation=90)
        ax3.set_xlabel('base-pairs/helical turn')
        ax3.set_xticks(range(0, len(grp2.tw)))
        ax3.set_xticklabels(grp2.tw, rotation=90)
        ax4.set_xlabel('base-pairs/helical turn')
        ax4.set_xticks(range(0, len(grp2.tw)))
        ax4.set_xticklabels(grp2.tw, rotation=90)
        ax5.set_xlabel('base-pairs/helical turn')
        ax5.set_xticks(range(0, len(grp2.tw)))
        ax5.set_xticklabels(grp2.tw, rotation=90)
        
        plt.legend(loc="upper left", bbox_to_anchor=(1.03,1), fancybox=True)
        plt.tight_layout()
        plt.savefig("col150_Wr_"+incons[i]+"_"+inseqs2[j]+"_4TwModel", dpi=200, transparent=True, bbox_inches='tight')
        #plt.show()
        plt.clf()
        
        fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)
        for key, grp in df2.groupby(['forcefield']):
            for key2, grp2 in grp.groupby(['seq_type']):
                if seqvars[0] == key2:
                    grp2.plot(kind='line', x='tw', y='Lk', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax1)
                elif seqvars[1] == key2:
                    grp2.plot(kind='line', x='tw', y='Lk', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax2)
                elif seqvars[2] == key2:
                    grp2.plot(kind='line', x='tw', y='Lk', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax3)
                elif seqvars[3] == key2:
                    grp2.plot(kind='line', x='tw', y='Lk', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax4)
                elif seqvars[4] == key2:
                    grp2.plot(kind='line', x='tw', y='Lk', c = statecolors[key], marker=statemarks[key], lw=1, legend=True, label=key, ax=ax5)
        
        ax1.set_ylim(12, 18)
        ax1.set_ylabel("Linking Number")
        ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
        ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
        ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
        ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
        ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
        
        ax1.set_xlabel('base-pairs/helical turn')
        ax1.set_xticks(range(0, len(grp2.tw)))
        ax1.set_xticklabels(grp2.tw, rotation=90)
        ax2.set_xlabel('base-pairs/helical turn')
        ax2.set_xticks(range(0, len(grp2.tw)))
        ax2.set_xticklabels(grp2.tw, rotation=90)
        ax3.set_xlabel('base-pairs/helical turn')
        ax3.set_xticks(range(0, len(grp2.tw)))
        ax3.set_xticklabels(grp2.tw, rotation=90)
        ax4.set_xlabel('base-pairs/helical turn')
        ax4.set_xticks(range(0, len(grp2.tw)))
        ax4.set_xticklabels(grp2.tw, rotation=90)
        ax5.set_xlabel('base-pairs/helical turn')
        ax5.set_xticks(range(0, len(grp2.tw)))
        ax5.set_xticklabels(grp2.tw, rotation=90)
        
        plt.legend(loc="upper left", bbox_to_anchor=(1.03,1), fancybox=True)
        plt.tight_layout()
        plt.savefig("col150_Lk_"+incons[i]+"_"+inseqs2[j]+"_4TwModel", dpi=200, transparent=True, bbox_inches='tight')
        #plt.show()
        plt.clf()
        
        fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)
        for key, grp in df2.groupby(['forcefield']):
            for key2, grp2 in grp.groupby(['seq_type']):
                if seqvars[0] == key2:
                    grp2.plot(kind='line', x='tw', y='Rg', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax1)
                elif seqvars[1] == key2:
                    grp2.plot(kind='line', x='tw', y='Rg', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax2)
                elif seqvars[2] == key2:
                    grp2.plot(kind='line', x='tw', y='Rg', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax3)
                elif seqvars[3] == key2:
                    grp2.plot(kind='line', x='tw', y='Rg', c = statecolors[key], marker=statemarks[key], lw=1, legend=False, label=key, ax=ax4)
                elif seqvars[4] == key2:
                    grp2.plot(kind='line', x='tw', y='Rg', c = statecolors[key], marker=statemarks[key], lw=1, legend=True, label=key, ax=ax5)
        ax1.set_ylim(60, 84)
        ax1.set_ylabel("Radius of Gyration")
        ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
        ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
        ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
        ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
        ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
        
        ax1.set_xlabel('base-pairs/helical turn')
        ax1.set_xticks(range(0, len(grp2.tw)))
        ax1.set_xticklabels(grp2.tw, rotation=90)
        ax1.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
        ax2.set_xlabel('base-pairs/helical turn')
        ax2.set_xticks(range(0, len(grp2.tw)))
        ax2.set_xticklabels(grp2.tw, rotation=90)
        ax2.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
        ax3.set_xlabel('base-pairs/helical turn')
        ax3.set_xticks(range(0, len(grp2.tw)))
        ax3.set_xticklabels(grp2.tw, rotation=90)
        ax3.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
        ax4.set_xlabel('base-pairs/helical turn')
        ax4.set_xticks(range(0, len(grp2.tw)))
        ax4.set_xticklabels(grp2.tw, rotation=90)
        ax4.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
        ax5.set_xlabel('base-pairs/helical turn')
        ax5.set_xticks(range(0, len(grp2.tw)))
        ax5.set_xticklabels(grp2.tw, rotation=90)
        ax5.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
        
        plt.legend(loc="upper left", bbox_to_anchor=(1.03,1), fancybox=True)
        plt.tight_layout()
        plt.savefig("col150_Rg_"+incons[i]+"_"+inseqs2[j]+"_4TwModel", dpi=200, transparent=True, bbox_inches='tight')
        #plt.show()
        plt.clf()
        
        del df2, grp, grp2
        fig_move(path)

# %% [raw]
# # Bar graphs of Initial and Optimized Energy/Rigid Body Parameters values
#
# for i in range(0, len(incons)):
#     for j in range(0, len(inseqs1)):
#         for k in range(0, len(ff_st)):
#             df2 = col150_df.loc[(col150_df.incon==incons[i])
#                                 & (col150_df.seq==inseqs1[j])
#                                 & (col150_df.forcefield==ff_st[k])
#                                 & (col150_df.tw != 'na')]
#
#             fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(20, 5), sharey=True)
#             #for key, grp in df2.groupby(['forcefield']):
#             for key2, grp2 in df2.groupby(['seq_type']):
#                 if seqvars[0] == key2:
#                     grp2.loc[:, ['tw', 'eopt-tilt', 'eopt-roll', 'eopt-twist']].plot.bar(stacked=True, x='tw', width=0.85, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax1)
#                 elif seqvars[1] == key2:
#                     grp2.loc[:, ['tw', 'eopt-tilt', 'eopt-roll', 'eopt-twist']].plot.bar(stacked=True, x='tw', width=0.85, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax2)
#                 elif seqvars[2] == key2:
#                     grp2.loc[:, ['tw', 'eopt-tilt', 'eopt-roll', 'eopt-twist']].plot.bar(stacked=True, x='tw', width=0.85, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax3)
#                 elif seqvars[3] == key2:
#                     grp2.loc[:, ['tw', 'eopt-tilt', 'eopt-roll', 'eopt-twist']].plot.bar(stacked=True, x='tw', width=0.85, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax4)
#                 elif seqvars[4] == key2:
#                     grp2.loc[:, ['tw', 'eopt-tilt', 'eopt-roll', 'eopt-twist']].plot.bar(stacked=True, x='tw', width=0.85, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=True, ax=ax5)
#
#             ax1.set_ylim(0, 75)
#             ax1.set_ylabel("Optimized Energy (kBT)")
#             ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
#             ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
#             ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
#             ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
#             ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#             ax1.set_xlabel('base-pairs/helical turn')
#             ax1.set_xticks(range(0, len(grp2.tw)))
#             ax1.set_xticklabels(grp2.tw, rotation=90)
#             ax2.set_xlabel('base-pairs/helical turn')
#             ax2.set_xticks(range(0, len(grp2.tw)))
#             ax2.set_xticklabels(grp2.tw, rotation=90)
#             ax3.set_xlabel('base-pairs/helical turn')
#             ax3.set_xticks(range(0, len(grp2.tw)))
#             ax3.set_xticklabels(grp2.tw, rotation=90)
#             ax4.set_xlabel('base-pairs/helical turn')
#             ax4.set_xticks(range(0, len(grp2.tw)))
#             ax4.set_xticklabels(grp2.tw, rotation=90)
#             ax5.set_xlabel('base-pairs/helical turn')
#             ax5.set_xticks(range(0, len(grp2.tw)))
#             ax5.set_xticklabels(grp2.tw, rotation=90)
#
#             plt.legend(title=ff_st[k], loc="upper left", bbox_to_anchor=(1.03,1), fancybox=True)
#             plt.tight_layout()
#             plt.savefig("col150_Stacked-Eopt_"+incons[i]+"_"+ff_st[k]+"_"+inseqs2[j]+"_4TwModel", dpi=200, transparent=True, bbox_inches='tight')
#             #plt.show()
#             plt.clf()
#
#             del df2
#             fig_move(path)

# %% [raw]
# for i in range(0, len(incons)):
#     for j in range(0, len(inseqs1)):
#         df2 = col150_df.loc[(col150_df.incon==incons[i])
#                              & (col150_df.seq==inseqs1[j])
#                              & (col150_df.tw == 'na')]
#         fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(15, 5), sharey=True)
#         #for key, grp in df2.groupby(['forcefield']):
#         for key, grp in df2.groupby(['seq_type']):
#             if seqvars[0] == key:
#                 grp.loc[:, 'eopt'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax1)
#             elif seqvars[1] == key:
#                 grp.loc[:, 'eopt'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax2)
#             elif seqvars[2] == key:
#                 grp.loc[:, 'eopt'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax3)
#             elif seqvars[3] == key:
#                 grp.loc[:, 'eopt'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax4)
#             elif seqvars[4] == key:
#                 grp.loc[:, 'eopt'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax5)
#
#         ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
#         ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
#         ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
#         ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
#         ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#         ax1.set_ylim(0, 75)
#         ax1.set_ylabel("Optimized Energy (kBT)")
#         ax1.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax2.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax3.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax4.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax5.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         plt.tight_layout()
#         plt.savefig("col150_Eopt_"+incons[i]+"_3Model_"+inseqs2[j]+"_bar", dpi=200, transparent=True, bbox_inches='tight')
#         #plt.show()
#         plt.clf()
#
#         fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(15, 5), sharey=True)
#         #for key, grp in df2.groupby(['forcefield']):
#         for key, grp in df2.groupby(['seq_type']):
#             if seqvars[0] == key:
#                 grp.loc[:, 'Lk'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax1)
#             elif seqvars[1] == key:
#                 grp.loc[:, 'Lk'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax2)
#             elif seqvars[2] == key:
#                 grp.loc[:, 'Lk'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax3)
#             elif seqvars[3] == key:
#                 grp.loc[:, 'Lk'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax4)
#             elif seqvars[4] == key:
#                 grp.loc[:, 'Lk'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax5)
#
#         ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
#         ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
#         ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
#         ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
#         ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#         ax1.set_ylim(12, 18)
#         ax1.set_ylabel("Linking Number")
#         ax1.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax2.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax3.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax4.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax5.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         plt.tight_layout()
#         plt.savefig("col150_Lk_"+incons[i]+"_3Model_"+inseqs2[j]+"_bar", dpi=200, transparent=True, bbox_inches='tight')
#         #plt.show()
#         plt.clf()
#
#         fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(15, 5), sharey=True)
#         #for key, grp in df2.groupby(['forcefield']):
#         for key, grp in df2.groupby(['seq_type']):
#             if seqvars[0] == key:
#                 grp.loc[:, 'Wr'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax1)
#             elif seqvars[1] == key:
#                 grp.loc[:, 'Wr'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax2)
#             elif seqvars[2] == key:
#                 grp.loc[:, 'Wr'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax3)
#             elif seqvars[3] == key:
#                 grp.loc[:, 'Wr'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax4)
#             elif seqvars[4] == key:
#                 grp.loc[:, 'Wr'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax5)
#
#         ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
#         ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
#         ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
#         ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
#         ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#         ax1.set_ylim(-0.5, 0.5)
#         ax1.set_ylabel("Writhe")
#         ax1.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax2.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax3.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax4.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax5.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         plt.tight_layout()
#         plt.savefig("col150_Wr_"+incons[i]+"_3Model_"+inseqs2[j]+"_bar", dpi=200, transparent=True, bbox_inches='tight')
#         #plt.show()
#         plt.clf()
#
#         fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(15, 5), sharey=True)
#         #for key, grp in df2.groupby(['forcefield']):
#         for key, grp in df2.groupby(['seq_type']):
#             if seqvars[0] == key:
#                 grp.loc[:, 'Rg'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax1)
#             elif seqvars[1] == key:
#                 grp.loc[:, 'Rg'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax2)
#             elif seqvars[2] == key:
#                 grp.loc[:, 'Rg'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax3)
#             elif seqvars[3] == key:
#                 grp.loc[:, 'Rg'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax4)
#             elif seqvars[4] == key:
#                 grp.loc[:, 'Rg'].plot.bar(stacked=False, x='forcefield', width=1, edgecolor='black', color=['darkgreen', 'crimson', 'dodgerblue'], legend=False, ax=ax5)
#
#         ax1.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 0% C', transform=ax1.transAxes, verticalalignment='top')
#         ax2.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' ~3% C', transform=ax2.transAxes, verticalalignment='top')
#         ax3.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 10% C', transform=ax3.transAxes, verticalalignment='top')
#         ax4.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 13% C', transform=ax4.transAxes, verticalalignment='top')
#         ax5.text(0.05, 0.95, incons[i]+': '+inseqs2[j]+' 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#         ax1.set_ylim(70, 84)
#         ax1.set_ylabel("Radius of Gyration")
#         ax1.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax2.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax3.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax4.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         ax5.set_xticklabels(['Ideal\nB-DNA','Trifonov\nModel','Olson\nSeq.Dep'], rotation=0)
#         plt.tight_layout()
#         plt.savefig("col150_Rg_"+incons[i]+"_3Model_"+inseqs2[j]+"_bar", dpi=200, transparent=True, bbox_inches='tight')
#         #plt.show()
#         plt.clf()
#
#         del df2, grp
#         fig_move(path)

# %% [raw]
# seqvars  = ['stda','c05a','c15a','c20a','c30a']
# seqvarcolors = {'stda':'grey','c05a':'blue','c15a':'red','c20a':'gold','c30a':'green'}
# seqvarmarks  = {'stda':'s','c05a':'<','c15a':'^','c20a':'d','c30a':'P'}
# ff_st    = [str(i)+'-state' for i in range(1, 5, 1)]
# statecolors  = {'1-state':'gold','2-state':'dodgerblue','3-state':'limegreen','4-state':'tomato'}
# statemarks   = {'1-state':'.','2-state':'.','3-state':'.','4-state':'.'}
# ff_ind   = ['ideal','kabsch','olson']
# indffcolors  = {'ideal':'darkgreen','kabsch':'crimson','olson':'dodgerblue'}
#
#
# for i in range(0, len(incons)):
#     df = col150_df.loc[(col150_df.incon==incons[i]) & (col150_df.tw != 'na')]
#     fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(25,5))
#     for key, grp in df.groupby(['seq_type']):
#         if key == seqvars[0]:   grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax1)
#         elif key == seqvars[1]: grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax2)
#         elif key == seqvars[2]: grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax3)
#         elif key == seqvars[3]: grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax4)
#         elif key == seqvars[4]: grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax5)
#
#     ax1.text(0.05, 1.05, incons[i]+': 0% C', transform=ax1.transAxes, verticalalignment='top')
#     ax2.text(0.05, 1.05, incons[i]+': ~3% C', transform=ax2.transAxes, verticalalignment='top')
#     ax3.text(0.05, 1.05, incons[i]+': 10% C', transform=ax3.transAxes, verticalalignment='top')
#     ax4.text(0.05, 1.05, incons[i]+': 13% C', transform=ax4.transAxes, verticalalignment='top')
#     ax5.text(0.05, 1.05, incons[i]+': 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#     ax1.set_xlabel('Elastic Energy (kBT)')
#     ax2.set_xlabel('Elastic Energy (kBT)')
#     ax3.set_xlabel('Elastic Energy (kBT)')
#     ax4.set_xlabel('Elastic Energy (kBT)')
#     ax5.set_xlabel('Elastic Energy (kBT)')
#
#     ax1.set_xlim(0, 70)
#     ax2.set_xlim(0, 70)
#     ax3.set_xlim(0, 70)
#     ax4.set_xlim(0, 70)
#     ax5.set_xlim(0, 70)
#
#     ax1.set_ylabel('Writhe')
#     ax2.set_ylabel('Writhe')
#     ax3.set_ylabel('Writhe')
#     ax4.set_ylabel('Writhe')
#     ax5.set_ylabel('Writhe')
#
#     plt.tight_layout()
#     plt.savefig("col150_scatter-Eopt-Wr_"+incons[i]+"_4TwModel", dpi=200, transparent=True, bbox_inches='tight')
#     #plt.show()
#     plt.clf()
#
#     fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(25,5))
#     for key, grp in df.groupby(['seq_type']):
#         if key == seqvars[0]:   grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax1)
#         elif key == seqvars[1]: grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax2)
#         elif key == seqvars[2]: grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax3)
#         elif key == seqvars[3]: grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax4)
#         elif key == seqvars[4]: grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[statecolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax5)
#
#     ax1.text(0.05, 1.05, incons[i]+': 0% C', transform=ax1.transAxes, verticalalignment='top')
#     ax2.text(0.05, 1.05, incons[i]+': ~3% C', transform=ax2.transAxes, verticalalignment='top')
#     ax3.text(0.05, 1.05, incons[i]+': 10% C', transform=ax3.transAxes, verticalalignment='top')
#     ax4.text(0.05, 1.05, incons[i]+': 13% C', transform=ax4.transAxes, verticalalignment='top')
#     ax5.text(0.05, 1.05, incons[i]+': 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#     ax1.set_xlabel('Elastic Energy (kBT)')
#     ax2.set_xlabel('Elastic Energy (kBT)')
#     ax3.set_xlabel('Elastic Energy (kBT)')
#     ax4.set_xlabel('Elastic Energy (kBT)')
#     ax5.set_xlabel('Elastic Energy (kBT)')
#
#     ax1.set_xlim(0, 70)
#     ax2.set_xlim(0, 70)
#     ax3.set_xlim(0, 70)
#     ax4.set_xlim(0, 70)
#     ax5.set_xlim(0, 70)
#
#     ax1.set_ylabel("Radius of Gyration ($\AA$)")
#     ax2.set_ylabel("Radius of Gyration ($\AA$)")
#     ax3.set_ylabel("Radius of Gyration ($\AA$)")
#     ax4.set_ylabel("Radius of Gyration ($\AA$)")
#     ax5.set_ylabel("Radius of Gyration ($\AA$)")
#
#     ax1.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#     ax2.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#     ax3.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#     ax4.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#     ax5.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#
#     plt.tight_layout()
#     plt.savefig("col150_scatter-Eopt-Rg_"+incons[i]+"_4TwModel", dpi=200, transparent=True, bbox_inches='tight')
#     #plt.show()
#     plt.clf()
#
#     del df, grp
#
#
# for i in range(0, len(incons)):
#     df = col150_df.loc[(col150_df.incon==incons[i]) & (col150_df.tw == 'na')]
#     fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(25,5), sharey=True)
#     for key, grp in df.groupby(['seq_type']):
#         if key == seqvars[0]:   grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax1)
#         elif key == seqvars[1]: grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax2)
#         elif key == seqvars[2]: grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax3)
#         elif key == seqvars[3]: grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax4)
#         elif key == seqvars[4]: grp.plot.scatter(x='eopt', y='Wr', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax5)
#
#     ax1.text(0.05, 1.05, incons[i]+': 0% C', transform=ax1.transAxes, verticalalignment='top')
#     ax2.text(0.05, 1.05, incons[i]+': ~3% C', transform=ax2.transAxes, verticalalignment='top')
#     ax3.text(0.05, 1.05, incons[i]+': 10% C', transform=ax3.transAxes, verticalalignment='top')
#     ax4.text(0.05, 1.05, incons[i]+': 13% C', transform=ax4.transAxes, verticalalignment='top')
#     ax5.text(0.05, 1.05, incons[i]+': 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#     ax1.set_xlabel('Elastic Energy (kBT)')
#     ax2.set_xlabel('Elastic Energy (kBT)')
#     ax3.set_xlabel('Elastic Energy (kBT)')
#     ax4.set_xlabel('Elastic Energy (kBT)')
#     ax5.set_xlabel('Elastic Energy (kBT)')
#
#     ax1.set_xlim(0, 70)
#     ax2.set_xlim(0, 70)
#     ax3.set_xlim(0, 70)
#     ax4.set_xlim(0, 70)
#     ax5.set_xlim(0, 70)
#
#     ax1.set_ylabel('Writhe')
#     ax2.set_ylabel('Writhe')
#     ax3.set_ylabel('Writhe')
#     ax4.set_ylabel('Writhe')
#     ax5.set_ylabel('Writhe')
#
#     ax1.set_ylim(-0.10, 0.25)
#     ax2.set_ylim(-0.10, 0.25)
#     ax3.set_ylim(-0.10, 0.25)
#     ax4.set_ylim(-0.10, 0.25)
#     ax5.set_ylim(-0.10, 0.25)
#
#     plt.tight_layout()
#     plt.savefig("col150_scatter-Eopt-Wr_"+incons[i]+"_3Model", dpi=200, transparent=True, bbox_inches='tight')
#     #plt.show()
#     plt.clf()
#
#     fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(nrows=1, ncols=5, figsize=(25,5), sharey=True)
#     for key, grp in df.groupby(['seq_type']):
#         if key == seqvars[0]:   grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax1)
#         elif key == seqvars[1]: grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax2)
#         elif key == seqvars[2]: grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax3)
#         elif key == seqvars[3]: grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax4)
#         elif key == seqvars[4]: grp.plot.scatter(x='eopt', y='Rg', marker=seqvarmarks[key], c=[indffcolors.get(j) for j in grp.forcefield], alpha=0.5, ax=ax5)
#
#     ax1.text(0.05, 1.05, incons[i]+': 0% C', transform=ax1.transAxes, verticalalignment='top')
#     ax2.text(0.05, 1.05, incons[i]+': ~3% C', transform=ax2.transAxes, verticalalignment='top')
#     ax3.text(0.05, 1.05, incons[i]+': 10% C', transform=ax3.transAxes, verticalalignment='top')
#     ax4.text(0.05, 1.05, incons[i]+': 13% C', transform=ax4.transAxes, verticalalignment='top')
#     ax5.text(0.05, 1.05, incons[i]+': 20% C', transform=ax5.transAxes, verticalalignment='top')
#
#     ax1.set_xlabel('Elastic Energy (kBT)')
#     ax2.set_xlabel('Elastic Energy (kBT)')
#     ax3.set_xlabel('Elastic Energy (kBT)')
#     ax4.set_xlabel('Elastic Energy (kBT)')
#     ax5.set_xlabel('Elastic Energy (kBT)')
#
#     ax1.set_xlim(0, 70)
#     ax2.set_xlim(0, 70)
#     ax3.set_xlim(0, 70)
#     ax4.set_xlim(0, 70)
#     ax5.set_xlim(0, 70)
#
#     ax1.set_ylabel("Radius of Gyration ($\AA$)")
#     ax2.set_ylabel("Radius of Gyration ($\AA$)")
#     ax3.set_ylabel("Radius of Gyration ($\AA$)")
#     ax4.set_ylabel("Radius of Gyration ($\AA$)")
#     ax5.set_ylabel("Radius of Gyration ($\AA$)")
#
#     ax1.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#     ax2.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#     ax3.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#     ax4.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#     ax5.axhline(y=round(float((3.4/(2*np.pi))*Ncirc), 2), linestyle=':', color='grey')
#
#     ax1.set_ylim(70, 85)
#     ax2.set_ylim(70, 85)
#     ax3.set_ylim(70, 85)
#     ax4.set_ylim(70, 85)
#     ax5.set_ylim(70, 85)
#
#     plt.tight_layout()
#     plt.savefig("col150_scatter-Eopt-Rg_"+incons[i]+"_3Model", dpi=200, transparent=True, bbox_inches='tight')
#     #plt.show()
#     plt.clf()
#
#     del df, grp
# fig_move(path)

# %% [markdown]
# ## Load .par files into dataframes and analyze

# %% [raw]
# fig, ax = plt.subplots(figsize=(15, 5))
# for i in range(0, len(rstw)):
#     pardf = optparameterdf(path+'/opt_par/col09_oring_domA_vor'+str(rstw[i]).zfill(3)+'.par')
#     pardf[1:].plot.line(y='Bend', legend=False, ax=ax)
#     del pardf
# plt.show()
# plt.clf()
#
# fig, ax = plt.subplots(figsize=(15, 5))
# for i in range(0, len(rstw)):
#     pardf = optparameterdf(path+'/opt_par/col09_oring_domB_vor'+str(rstw[i]).zfill(3)+'.par')
#     pardf[1:].plot.line(y='Bend', legend=False, ax=ax)
#     del pardf
# plt.show()
# plt.clf()
