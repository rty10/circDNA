# %%
import os, sys, math, scipy
import pandas as pd
import numpy as np
from scipy.spatial import distance

path = os.getcwd()

# %%
ncppath = '/home/rty10/Documents/OARC/home_rty10_documents/databases/'
#ncppath = '/home/rty10/Documents/nuc_database/'

ncpcluster = pd.read_csv(ncppath+"ncps_curated_basepairs_v2.csv", index_col=False)

# %%
ncpcluster.loc[ncpcluster.ncp=='3azi']
# Out:
#       pdb_id   ncp  bpindex bpname  DSSR   LW  nt1_chi  nt1_flipped  nt2_chi  \
# 5108  3azi.1  3azi      -72    A-T  cW-W  cWW -123.977        False  -80.837
# 5109  3azi.1  3azi      -71    T-A  cW-W  cWW -105.169        False -108.026
# 5110  3azi.1  3azi      -70    C-G  cW-W  cWW -160.603        False  -83.569
# 5111  3azi.1  3azi      -69    A-T  cW-W  cWW -103.779        False  -86.098
# 5112  3azi.1  3azi      -68    A-T  cW-W  cWW  -76.857        False -104.084
# ...      ...   ...      ...    ...   ...  ...      ...          ...      ...
# 5248  3azi.1  3azi       68    A-T  cW-W  cWW  -90.150        False -140.326
# 5249  3azi.1  3azi       69    T-A  cW-W  cWW -115.142        False -103.868
# 5250  3azi.1  3azi       70    T-A  cW-W  cWW  -68.807        False  -84.542
# 5251  3azi.1  3azi       71    G-C  cW-W  cWW -109.184        False  -77.260
# 5252  3azi.1  3azi       72    A-T  cW-W  cWW -104.887        False -134.067
#
# ...
