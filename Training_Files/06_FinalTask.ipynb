# %% [raw]
# In this notebook, produce the following plots using the test_dnapdb.out file
#
# - Produce a 3D scatter plot of the Ox, Oy, Oz origin points of the structure
#
# - Plot the refined major and refinded minor groove widths
#
# - Plot the ratio of the P-P Virtual Bond distances between Strand I and II

# %%
import os
import pandas as pd
import numpy as np

path=os.getcwd()

PATH2 = "/mnt/c/Users/Young_Research/Documents/Rutgers/Research/forcefields/RestStateParameters"

# %%
print(path)
# Out:
# /mnt/c/Users/Young_Research/Documents/programming/Starter_JupyterNotebook

# %%
infile=open(path+"/test_dnapdb.out", "r")
DATA = infile.readlines()
infile.close()

print(DATA)
# Out:
# ["This structure has broken O3'[i] to P[i+1] linkages\n", '****************************************************************************\n', '    3DNA v2.4.4-2019sep09, created and maintained by xiangjun@x3dna.org\n', '****************************************************************************\n', "1. The list of the parameters given below correspond to the 5' to 3' direction\n", "   of strand I and 3' to 5' direction of strand II.\n", '\n', '2. All angular parameters, except for the phase angle of sugar pseudo-\n', '   rotation, are measured in degrees in the range of [-180, +180], and all\n', '   displacements are measured in Angstrom units.\n', '****************************************************************************\n', 'File name: test_dnapdb.pdb\n', 'Date and time: Fri Jun  5 13:17:08 2020\n', '\n', 'Number of base-pairs: 200\n', 'Number of atoms: 8200\n', '****************************************************************************\n', '************************************
# ...

# %%
infile=open(PATH2+"/StepParameters_Olson1998.txt", "r")
pars = infile.readlines()
infile.close()

print(pars)
# Out:
# ['AA={-1.4, 0.7, 35.1, -0.03, -0.08, 3.27}\n', 'AC={-0.1, 0.7, 31.5, 0.13, -0.58, 3.36}\n', 'AG={-1.7, 4.5, 31.9, 0.09, -0.25, 3.34}\n', 'AT={0., 1.1, 29.3, 0., -0.59, 3.31}\n', 'CA={0.5, 4.7, 37.3, 0.09, 0.53, 3.33}\n', 'CC={0.1, 3.6, 32.9, -0.05, -0.22, 3.42}\n', 'CG={0., 5.4, 36.1, 0., 0.41, 3.39}\n', 'CT={1.5, 1.9, 36.3, 0.28, 0.09, 3.37}\n', 'GA={-1.5, 1.9, 36.3, -0.28, 0.09, 3.37}\n', 'GC={0., 0.3, 33.6, 0., -0.38, 3.40}\n', 'GG={-0.1, 3.6, 32.9, 0.05, -0.22, 3.42}}\n', 'GT={-0.5, 4.7, 37.3, -0.09, 0.53, 3.33}\n', 'TA={0., 3.3, 37.8, 0., 0.05, 3.42}\n', 'TC={1.7, 4.5, 31.9, -0.09, -0.25, 3.34}\n', 'TG={0.1, 0.7, 31.5, -0.13, -0.58, 3.36}\n', 'TT={1.4, 0.7, 35.1, 0.03, -0.08, 3.27}']
